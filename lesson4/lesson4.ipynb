# %%
import pandas as pd 
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
students_performance = pd.read_csv('StudentsPerformance.csv')

# %%
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score
# ...

# %%
students_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
students_performance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', fit_reg = False, data=students_performance)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
df = pd.read_csv('income.csv')

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df.income)

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
points = pd.read_csv('dataset.txt', sep=' ')

# %%
points
# Out:
#               x            y
# 0   1098.461114   700.793103
# 1   1488.835100  1296.576278
# 2    209.820314   199.991900
# 3     95.171341  1108.898006
# 4    899.473430   606.586265
# ..          ...          ...
# 85    93.666597  1101.391852
# 86   602.541767    95.944535
# 87   502.467888   807.042233
# 88   604.767848   107.814532
# 89   895.139840   593.111940
#
# [90 rows x 2 columns]

# %%
points.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.lmplot(x='x',y='y',data=points)

# %%
sns.scatterplot(x='x',y='y',data=points)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
genome_matrix = pd.read_csv('genome_matrix.csv', index_col=0)
genome_matrix
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(data=genome_matrix,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
dota_heroes = pd.read_csv('dota_hero_stats.csv', index_col=0)
dota_heroes
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles
# ...

# %%
arr = dota_heroes.roles

# %%
for i in range(len(arr)):
    arr[i] = arr[i].count("'")/2;
# Out:
# <ipython-input-23-fb729f8b3ff8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   arr[i] = arr[i].count("'")/2;

# %%
arr.hist()
# Out:
# <AxesSubplot:>

# %%
iris = pd.read_csv('iris.csv', index_col=0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
for column in iris:
    iris[[column]].hist()

# %%
sns.violinplot(data=iris['petal length'])
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(iris)
